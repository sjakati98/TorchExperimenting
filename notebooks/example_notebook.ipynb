# %% [markdown]
# # 🔥 PyTorch Experimentation Notebook
#
# Example notebook to get you started with interactive PyTorch experiments.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

print(f"PyTorch version: {torch.__version__}")
# Out:
# PyTorch version: 2.9.1

# %% [markdown]
# ## 📱 Device Setup

# %%
def get_device():
    """Get the best available device"""
    if torch.backends.mps.is_available():
        return torch.device("mps")
    elif torch.cuda.is_available():
        return torch.device("cuda")
    else:
        return torch.device("cpu")

device = get_device()
print(f"Using device: {device}")
# Out:
# Using device: mps

# %% [markdown]
# ## 🧠 Your Experiments
#
# Start experimenting below!

# %%
# Example: Create a simple tensor
x = torch.randn(5, 5).to(device)
print(x)
# Out:
# tensor([[-0.7578, -0.4236, -1.1394,  0.6064, -1.8508],
#         [ 0.9197, -0.6262,  0.8189, -1.2090, -1.3856],
#         [ 1.3837, -0.5915, -1.0823,  0.2240,  0.8781],
#         [ 0.3189, -0.4166, -0.3019, -0.0695,  1.7743],
#         [ 0.9749, -1.4351,  1.4402,  0.1298, -0.5419]], device='mps:0')

# %%
# Example: Simple neural network
model = nn.Sequential(
    nn.Linear(10, 64),
    nn.ReLU(),
    nn.Linear(64, 2)
).to(device)

print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Model parameters: 834

# %% [markdown]
# ## 📊 Visualization

# %%
# Example: Plot some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title("Example Plot")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()
